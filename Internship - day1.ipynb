# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading CSV Files

# %%
data = pd.read_csv(r"C:\Users\sravani\Downloads\1991-2011.csv")

# %% [markdown]
# # Few Panda functions

# %%
data.head()
# Out:
#    Year  Total Population       Male     Female  Rural Population  \
# 0  1901         238396327  120791301  117358672         212544454
# 1  1911         252093390  128385368  123708022         226151757
# 2  1921         251321213  128546225  122774988         223235043
# 3  1931         278977238  142929689  135788921         245521249
# 4  1941         318660580  163685302  154690267         274507283
#
#    Urban Population  Decadal Growth Percentage  0-5 Years  6-15 Years  \
# 0          25851873                        NaN        NaN         NaN
# 1          25941633                       5.75        NaN         NaN
# 2          28086170                       0.31        NaN         NaN
# 3          33455989                      11.00        NaN         NaN
# 4          44153297                      14.22        NaN         NaN
#
#    16-35 Years       ...        Sex Ratio females per 1000 males  \
# 0          NaN       ...                                     972
# ...

# %%
data.tail()
# Out:
#     Year  Total Population       Male     Female  Rural Population  \
# 7   1971         548159652  284049276  264110376         439045675
# 8   1981         683329097  353374460  329954637         523866550
# 9   1991         846427039  439358440  407062599         628691676
# 10  2001        1028737436  532223090  496514346         742490639
# 11  2011        1210193422  623270258  587584719         833087662
#
#     Urban Population  Decadal Growth Percentage  0-5 Years  6-15 Years  \
# 7          109113977                      24.80        NaN         NaN
# 8          159462547                      24.66        NaN         NaN
# 9          217611012                      23.87        NaN         NaN
# 10         286119689                      21.54        NaN         NaN
# 11         377105760                      17.64        NaN         NaN
#
#     16-35 Years       ...        Sex Ratio females per 1000 males  \
# ...

# %%
data1 = pd.read_csv(r"C:\Users\sravani\Downloads\1991-2011.csv",header=[1,2])

# %%
data1.head()
# Out:
#    1901  238396327  120791301  117358672  212544454  25851873  \
#    1911  252093390  128385368  123708022  226151757  25941633
# 0  1921  251321213  128546225  122774988  223235043  28086170
# 1  1931  278977238  142929689  135788921  245521249  33455989
# 2  1941  318660580  163685302  154690267  274507283  44153297
# 3  1951  361088090  185528462  175559628  298644381  62443709
# 4  1961  439234771  226293201  212941570  360298168  78936603
#
#   Unnamed: 6_level_0 Unnamed: 7_level_0 Unnamed: 8_level_0 Unnamed: 9_level_0  \
#                 5.75 Unnamed: 7_level_1 Unnamed: 8_level_1 Unnamed: 9_level_1
# 0               0.31                NaN                NaN                NaN
# 1              11.00                NaN                NaN                NaN
# 2              14.22                NaN                NaN                NaN
# 3              13.31                NaN                NaN                NaN
# ...

# %%
data1 = pd.read_csv(r"C:\Users\sravani\Downloads\1991-2011.csv",names=["ant","bat"],header=1)
data1.head()
# Out:
#                                                                                                                            ant  \
# 1911 252093390 128385368 123708022 226151757 25941633 5.75  NaN NaN NaN NaN NaN 964 5.92  NaN   NaN   NaN NaN  NaN  NaN    NaN
# 1921 251321213 128546225 122774988 223235043 28086170 0.31  NaN NaN NaN NaN NaN 955 7.16  NaN   NaN   NaN NaN  NaN  NaN    NaN
# 1931 278977238 142929689 135788921 245521249 33455989 11.00 NaN NaN NaN NaN NaN 950 9.50  NaN   NaN   NaN NaN  NaN  NaN    NaN
# 1941 318660580 163685302 154690267 274507283 44153297 14.22 NaN NaN NaN NaN NaN 945 16.10 NaN   NaN   NaN NaN  NaN  NaN    NaN
# 1951 361088090 185528462 175559628 298644381 62443709 13.31 NaN NaN NaN NaN NaN 946 18.33 84.14 9.80  2.3 1.79 0.74 0.46  0.13
#
#                                                                                                                           bat
# ...

# %%
data1 = pd.read_csv(r"C:\Users\sravani\Downloads\1991-2011.csv",nrows=2)
data1
# Out:
#    Year  Total Population       Male     Female  Rural Population  \
# 0  1901         238396327  120791301  117358672         212544454
# 1  1911         252093390  128385368  123708022         226151757
#
#    Urban Population  Decadal Growth Percentage  0-5 Years  6-15 Years  \
# 0          25851873                        NaN        NaN         NaN
# 1          25941633                       5.75        NaN         NaN
#
#    16-35 Years       ...        Sex Ratio females per 1000 males  \
# 0          NaN       ...                                     972
# 1          NaN       ...                                     964
#
#    Literacy Rate  Total Hindus  Total Muslims  Total Christianity  \
# 0           5.35           NaN            NaN                 NaN
# 1           5.92           NaN            NaN                 NaN
#
#    Total sikhs  Total Buddhists  Total Jains  Total Zoroastrians  \
# 0          NaN              NaN          NaN                 NaN
# ...

# %%
dp=data1.loc[data1["Year"]==1901]
# Out:
#    Year  Total Population       Male     Female  Rural Population  \
# 0  1901         238396327  120791301  117358672         212544454
#
#    Urban Population  Decadal Growth Percentage  0-5 Years  6-15 Years  \
# 0          25851873                        NaN        NaN         NaN
#
#    16-35 Years       ...        Sex Ratio females per 1000 males  \
# 0          NaN       ...                                     972
#
#    Literacy Rate  Total Hindus  Total Muslims  Total Christianity  \
# 0           5.35           NaN            NaN                 NaN
#
#    Total sikhs  Total Buddhists  Total Jains  Total Zoroastrians  \
# 0          NaN              NaN          NaN                 NaN
#
#    Total adivasis
# 0             NaN
#
# [1 rows x 22 columns]

# %%
data.head()
# Out:
#    Year  Total Population       Male     Female  Rural Population  \
# 0  1901         238396327  120791301  117358672         212544454
# 1  1911         252093390  128385368  123708022         226151757
# 2  1921         251321213  128546225  122774988         223235043
# 3  1931         278977238  142929689  135788921         245521249
# 4  1941         318660580  163685302  154690267         274507283
#
#    Urban Population  Decadal Growth Percentage  \
# 0          25851873                        NaN
# 1          25941633                       5.75
# 2          28086170                       0.31
# 3          33455989                      11.00
# 4          44153297                      14.22
#
#    Sex Ratio females per 1000 males  Literacy Rate  Total Hindus  \
# 0                               972           5.35           NaN
# 1                               964           5.92           NaN
# 2                               955           7.16           NaN
# ...

# %%
data.iloc[1:5,2:5]
# Out:
#         Male     Female  Rural Population
# 1  128385368  123708022         226151757
# 2  128546225  122774988         223235043
# 3  142929689  135788921         245521249
# 4  163685302  154690267         274507283

# %%
data.drop(["0-5 Years","6-15 Years","16-35 Years","36-59 Years","60+ Years"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    Year  Total Population       Male     Female  Rural Population  \
# 0  1901         238396327  120791301  117358672         212544454
# 1  1911         252093390  128385368  123708022         226151757
# 2  1921         251321213  128546225  122774988         223235043
# 3  1931         278977238  142929689  135788921         245521249
# 4  1941         318660580  163685302  154690267         274507283
#
#    Urban Population  Decadal Growth Percentage  \
# 0          25851873                        NaN
# 1          25941633                       5.75
# 2          28086170                       0.31
# 3          33455989                      11.00
# 4          44153297                      14.22
#
#    Sex Ratio females per 1000 males  Literacy Rate  Total Hindus  \
# 0                               972           5.35           NaN
# 1                               964           5.92           NaN
# 2                               955           7.16           NaN
# ...

# %%
data.isnull().sum()
# Out:
# Year                                0
# Total Population                    0
# Male                                0
# Female                              0
# Rural Population                    0
# Urban Population                    0
# Decadal Growth Percentage           1
# Sex Ratio females per 1000 males    0
# Literacy Rate                       0
# Total Hindus                        5
# Total Muslims                       5
# Total Christianity                  5
# Total sikhs                         5
# Total Buddhists                     5
# Total Jains                         5
# Total Zoroastrians                  6
# Total adivasis                      5
# dtype: int64

# %%
data.fillna(0)
# Out:
#     Year  Total Population       Male     Female  Rural Population  \
# 0   1901         238396327  120791301  117358672         212544454
# 1   1911         252093390  128385368  123708022         226151757
# 2   1921         251321213  128546225  122774988         223235043
# 3   1931         278977238  142929689  135788921         245521249
# 4   1941         318660580  163685302  154690267         274507283
# 5   1951         361088090  185528462  175559628         298644381
# 6   1961         439234771  226293201  212941570         360298168
# 7   1971         548159652  284049276  264110376         439045675
# 8   1981         683329097  353374460  329954637         523866550
# 9   1991         846427039  439358440  407062599         628691676
# 10  2001        1028737436  532223090  496514346         742490639
# 11  2011        1210193422  623270258  587584719         833087662
#
#     Urban Population  Decadal Growth Percentage  \
# ...

# %%
data.columns
# Out:
# Index(['Year', 'Total Population', 'Male', 'Female', 'Rural Population',
#        'Urban Population', 'Decadal Growth Percentage',
#        'Sex Ratio females per 1000 males', 'Literacy Rate', 'Total Hindus',
#        'Total Muslims', 'Total Christianity', 'Total sikhs', 'Total Buddhists',
#        'Total Jains', 'Total Zoroastrians', 'Total adivasis'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Year                                  int64
# Total Population                      int64
# Male                                  int64
# Female                                int64
# Rural Population                      int64
# Urban Population                      int64
# Decadal Growth Percentage           float64
# Sex Ratio females per 1000 males      int64
# Literacy Rate                       float64
# Total Hindus                        float64
# Total Muslims                       float64
# Total Christianity                  float64
# Total sikhs                         float64
# Total Buddhists                     float64
# Total Jains                         float64
# Total Zoroastrians                  float64
# Total adivasis                      float64
# dtype: object

# %%
data.shape
# Out:
# (12, 17)

# %% [markdown]
# # Reading excel files

# %%
data3 = pd.read_excel(r"C:\Users\sravani\Downloads\sample.xlsx")

# %%
data3.head()
# Out:
#       Segment  Country    Product Discount Band  Units Sold  \
# 0  Government   Canada  Carretera          None      1618.5
# 1  Government  Germany  Carretera          None      1321.0
# 2   Midmarket   France  Carretera          None      2178.0
# 3   Midmarket  Germany  Carretera          None       888.0
# 4   Midmarket   Mexico  Carretera          None      2470.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts    Sales     COGS  \
# 0                    3          20      32370.0        0.0  32370.0  16185.0
# 1                    3          20      26420.0        0.0  26420.0  13210.0
# 2                    3          15      32670.0        0.0  32670.0  21780.0
# 3                    3          15      13320.0        0.0  13320.0   8880.0
# 4                    3          15      37050.0        0.0  37050.0  24700.0
#
#     Profit       Date  Month Number Month Name  Year
# 0  16185.0 2014-01-01             1    January  2014
# ...

# %% [markdown]
# # Reading text files

# %%
data4 = pd.read_csv(r"C:\Users\sravani\Downloads\sample.txt", sep=',')
data4.head()
# Out:
#     id     sex  glucose  insulin  triglyc
# 0  101    Male    134.1     0.60    273.4
# 1  102  Female    120.0     1.18    243.6
# 2  103    Male    124.8     1.23    297.6
# 3  104    Male     83.1     1.16    142.4
# 4  105    Male    105.2     0.73    215.7

# %% [markdown]
# # Reading json file

# %%
data5=pd.read_json(r"C:\Users\sravani\Downloads\sampe1.json")
data5.head()
# Out:
#             Product  Price
# 0  Desktop Computer    700
# 1            Tablet    250
# 2            iPhone    800
# 3            Laptop   1200

# %% [markdown]
# # Conversion of DataFrame to files

# %% [markdown]
# ### To CSV

# %%
data4.to_csv (r"C:\Users\sravani\Downloads\conv1.csv", index=None)

# %% [markdown]
# ## To Excel

# %%
data4.to_excel (r"C:\Users\sravani\Downloads\conv1.xlsx", index=None)

# %% [markdown]
# ## To JSON

# %%
data4.to_json (r"C:\Users\sravani\Downloads\conv1.json")
